# %%
df <- read.csv("../data-generation/cpluplus_vViktor/trainingData/labels.txt", header=FALSE)

# %%
plot(df$V1, df$V2)
# Out:
# plot without title

# %%
plot(density(df$V1))
# Out:
# Plot with title "density.default(x = df$V1)"

# %%
plot(density(df$V2))
# Out:
# Plot with title "density.default(x = df$V2)"

# %%
ks.test(df$V1,"punif",-1,1)
# Out:
# 	One-sample Kolmogorov-Smirnov test
#
# data:  df$V1
# D = 0.069487, p-value = 0.0001279
# alternative hypothesis: two-sided
